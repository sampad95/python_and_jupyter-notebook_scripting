# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 580
x = np.arange(-n, n+1, 1)
Θ = x*np.pi/180

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(2*Θ), 3)
y2 = np.round(np.sin(3*Θ), 3)

#y2 = np.round(np.cos(Θ), 3)
#y = np.round(np.sin(2*Θ)+np.cos(3*Θ), 3)
#y = np.round(np.sin(2*Θ)+np.sin(3*Θ), 3)

m = 31
sin_odd = [np.sin(i*Θ) for i in range(1, m, 2)]
sin_even = [np.sin(i*Θ) for i in range(0, m, 2)]
#print(len(sin_odd))
cos_odd = [np.cos(i*Θ) for i in range(1, m, 2)]
cos_even = [np.cos(i*Θ) for i in range(0, m, 2)]

sin_odd_sum = sum(sin_odd)
#sin_even_sum = sum(sin_even)
cos_odd_sum = sum(cos_odd)
cos_even_sum = sum(cos_even)


fig=plt.figure(figsize=(12,8),linewidth=50)
ax = fig.gca()
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
plt.grid(linestyle='--')

plt.plot(x, sin_odd_sum, lw=3, c='dodgerblue')
#plt.plot(x, cos_odd_sum, lw=3, c='r')
plt.plot(x, cos_even_sum, lw=3, c='tab:orange')

# plt.plot(x, y1, '--', lw =2, c='orange')
# plt.plot(x, y2, '--', lw=2, c='g')

r= list(range(0, -n-1, -90)) + list(range(0, n+1, 90))

plt.xticks([i for  i in r],
              labels = [str(i) for i in r] ,fontsize=15,fontweight='bold')

plt.yticks(fontsize=15,fontweight='bold')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

n = 360
x = np.arange(-n, n+1, 0.1)
Θ = x*np.pi/180

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(6*Θ), 3)
y2 = np.round(np.cos(6*Θ), 3)

m = 31
sin_odd = [np.sin(i*Θ) for i in range(1, m, 2)]
sin_even = [np.sin(i*Θ) for i in range(0, m, 2)]
#print(len(sin_odd))
cos_odd = [np.cos(i*Θ) for i in range(1, m, 2)]
cos_even = [np.cos(i*Θ) for i in range(0, m, 2)]

sin_odd_sum = sum(sin_odd)
#sin_even_sum = sum(sin_even)
cos_odd_sum = sum(cos_odd)
cos_even_sum = sum(cos_even)


fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
# ax.plot(Θ, y1, c='r')
# ax.plot(Θ, y2, c='g')

ax.plot(Θ, sin_odd_sum, c='dodgerblue')
ax.plot(Θ, cos_odd_sum, c='tab:orange')

#ax.set_rmax(1.5)
#ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5])  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

#ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

n = 360
x = np.arange(0, n+1, 1)
Θ = x*np.pi/180

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(Θ), 3)
y2 = np.round(np.cos(Θ), 3)

fig = plt.figure(figsize=(8,8))
plt.axes(projection='polar')
#plt.polar(Θ, y1, 'g')
for i in range(1, 4, 1):
    fsin = np.round(np.sin(i*Θ), 3)
    fcos = np.round(np.cos(i*Θ), 3)
#    plt.polar(Θ, fsin)
    plt.polar(Θ, fcos)

plt.grid(True)

#ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

#n = 180
n = 360
x = np.arange(0, n+1, 0.1)
Θ = x*np.pi/180

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(3*Θ), 3)
y2 = np.round(np.cos(6*Θ), 3)



fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
ax.plot(Θ, y1, c='r')
# ax.plot(Θ, y2, c='g')

#ax.set_rmax(1.5)
ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5])  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

#ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

#n = 180
#n = 360
# x = np.arange(0, n+1, 0.1)
# Θ = x*np.pi/180

# Θ = np.pi*np.arange(-5, 5, 1)

# y1 = np.round(np.sin(3*Θ), 3)
# y2 = np.round(np.cos(6*Θ), 3)

fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
def animate(n):
#    n = 360
    x = np.arange(0, n+1, 0.1)
    Θ = x*np.pi/180
    y1 = np.round(np.sin(3*Θ), 3)
    y2 = np.round(np.cos(6*Θ), 3)
    
    ax.clear()
    ax.plot(Θ, y1, c='r')
#    x.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5])  # Less radial ticks
#    ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)


#fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
#ax.plot(Θ, y1, c='r')
# ax.plot(Θ, y2, c='g')

#ax.set_rmax(1.5)
#ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5])  # Less radial ticks
# ax.set_rlabel_position(10)  # Move radial labels away from plotted line
# ax.grid(True)
n = 360
anim = FuncAnimation(fig, animate, frames=n, interval=20, repeat=True)
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import matplotlib.pyplot as plt
import numpy as np

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

#n = 180
n = 360
x = np.arange(0, n+1, 1)
Θ = x

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(7*Θ), 3)
#y2 = np.round(np.cos(6*Θ), 3)

fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})

ax.plot(Θ, y1, c='tab:pink')
#ax.plot(Θ, y2, c='g')

#ax.set_rmax(1.5)
ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.1])  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

#ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

#n = 180
# n = 360
# x = np.arange(0, n+1, 1)
# Θ = x

# Θ = np.pi*np.arange(-5, 5, 1)

fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
def animate(n):
#    n = 360
    x = np.arange(0, n+1, 1)
    Θ = x
    y1 = np.round(np.sin(3*Θ), 3)  
    ax.clear()
    ax.plot(Θ, y1, c='tab:pink')


#ax.set_rmax(1.5)
# ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.1])  # Less radial ticks
# ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

n = 360
anim = FuncAnimation(fig, animate, frames=n, interval=50, repeat=True)
from IPython.display import HTML
HTML(anim.to_html5_video())

# %%
import matplotlib.pyplot as plt
import numpy as np

# r = np.arange(0, 2, 0.01)
# theta = 2 * np.pi * r

n = 360
x = np.arange(0, n+1, 1)
#Θ = x*np.pi/180
Θ = x

# Θ = np.pi*np.arange(-5, 5, 1)

y1 = np.round(np.sin(Θ), 3)
y2 = np.round(np.cos(Θ), 3)

fig = plt.figure(figsize=(8,8))
plt.axes(projection='polar')
#plt.polar(Θ, y1, 'g')
for i in range(1, 5, 1):
    fsin = np.round(np.sin(i*Θ), 3)
    fcos = np.round(np.cos(i*Θ), 3)
#    plt.polar(Θ, fsin)
    plt.polar(Θ, fcos)

plt.grid(True)

#ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# setting the axes
# projection as polar
plt.axes(projection='polar')

# setting the length
# and number of petals
a = 1
n = 6

# creating an array
# containing the radian values
rads = np.arange(0, 2 * np.pi, 0.1)

# plotting the rose
for rad in rads:
	r = a * np.cos(n*rad)
	plt.polar(rad, r, 'g.')

# display the polar plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math


# setting the axes
# projection as polar
plt.axes(projection = 'polar')

# setting the length of
# axis of cardioid
a=4

# creating an array
# containing the radian values
rads = np.arange(0, (2 * np.pi), 0.1)

# plotting the cardioid
for rad in rads:
	r = a + (a*np.cos(rad))
	plt.polar(rad,r,'g.')

# display the polar plot
plt.show()

# %%
t = np.arange(0, 5, 0.0001)
ν = 3               # Ctrl+Shift+u+03bd
ω = 2*np.pi*ν       # Ctrl+Shift+u+03c9
Θ = ω*t             # Ctrl+Shift+u+0398

I = np.round(np.cos(Θ), 5)

fig=plt.figure(figsize=(12,8),linewidth=50)
ax = fig.gca()
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
plt.grid(linestyle='--')

plt.plot(t, I, lw=3, c='dodgerblue')

r= list(range(0, int(t[-1])+2, 1))

plt.xticks([i for  i in r],
              labels = [str(i) for i in r] ,fontsize=15,fontweight='bold')

plt.yticks(fontsize=15,fontweight='bold')


fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
ax.plot(Θ, I, c='r')

#ax.set_rmax(1.5)
ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5], fontsize=15)  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

plt.show()

# %%
t = np.arange(0, 5, 0.0001)
n = 3                 # number of betas/second
ω1 = 2*np.pi*n        # Ctrl+Shift+u+03c9
Θ1 = ω1*t             # Ctrl+Shift+u+0398
I = np.round(np.cos(Θ1), 5) # intensity 

# Alter ν and see the effect. When n=ν see what happens

ν = 0.5               # frequency: number pf cycles/second # Ctrl+Shift+u+03bd
ω2 = 2*np.pi*ν        # Ctrl+Shift+u+03c9
Θ2 = ω2*t             # Ctrl+Shift+u+0398
Y = np.round(np.cos(Θ2), 5)

fig=plt.figure(figsize=(12,8),linewidth=50)
ax = fig.gca()
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
plt.grid(linestyle='--')

plt.plot(t, I, lw=3, c='k')
plt.plot(t, Y, lw=3, c='tab:orange')
       
r= list(range(0, int(t[-1])+2, 1))

plt.xticks([i for  i in r],
              labels = [str(i) for i in r] ,fontsize=15,fontweight='bold')

plt.yticks(fontsize=15,fontweight='bold')


fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})
ax.plot(Θ2, I, lw=3, c='red')

#ax.set_rmax(1.5)
ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5], fontsize=15)  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

plt.show()

# %%
t = np.arange(0, 5, 0.0001)
n = 3                 # number of betas/second
ω1 = 2*np.pi*n        # Ctrl+Shift+u+03c9
Θ1 = ω1*t             # Ctrl+Shift+u+0398
I = np.round(np.cos(Θ1), 5) # intensity 

#ν = 0.5                 # frequency: number pf cycles/second # Ctrl+Shift+u+03bd
#ω2 = 2*np.pi*ν        # Ctrl+Shift+u+03c9
#Θ2 = ω2*t             # Ctrl+Shift+u+0398
#Y = np.round(np.cos(Θ2), 5)

fig=plt.figure(figsize=(12,8),linewidth=50)
ax = fig.gca()
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
plt.grid(linestyle='--')

plt.plot(t, I, lw=3, c='k')

# Alter ν and see the effect. When n=ν see what happens

for ν in list(np.arange(1, 4, 1)):
    ω2 = 2*np.pi*ν        # Ctrl+Shift+u+03c9
    Θ2 = ω2*t 
    Y = np.round(np.cos(Θ2), 5)
    plt.plot(t, Y, lw=3, ls = '--')
    
    

r= list(range(0, int(t[-1])+2, 1))

plt.xticks([i for  i in r],
              labels = [str(i) for i in r] ,fontsize=15,fontweight='bold')

plt.yticks(fontsize=15,fontweight='bold')


fig, ax = plt.subplots(figsize=(8,8), subplot_kw={'projection': 'polar'})

# Alter ν and see the effect. When n=ν see what happens

for ν in list(np.arange(1, 4, 1)):
    ω2 = 2*np.pi*ν        # Ctrl+Shift+u+03c9
    Θ2 = ω2*t 
    ax.plot(Θ2, I, lw=3)

#ax.set_rmax(1.5)
ax.set_rticks([-1.0, -0.5, 0, 0.5, 1, 1.5], fontsize=15)  # Less radial ticks
ax.set_rlabel_position(10)  # Move radial labels away from plotted line
ax.grid(True)

plt.show()
