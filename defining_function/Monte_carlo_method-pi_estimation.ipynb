# %%
# %matplotlib widget
import random as rnd
import math 
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %%
def vector(x, y, z):
    return x, y, z

# %%
r = vector(rnd.random(), rnd.random(), 0)

# %%
r
# Out:
# (0.5222661310841906, 0.04513339038051922, 0)

# %%
rx, ry, rz = r

# %%
rx
# Out:
# 0.5222661310841906

# %%
ry
# Out:
# 0.04513339038051922

# %%
rz
# Out:
# 0

# %%
math.sqrt(rx**2 + ry**2 + rz**2)
# Out:
# 0.5242126806982919

# %%
fig = plt.figure(figsize = [4, 4], linewidth = 50)
Cin = []
Cout = []
for i in range(10000):
    def vector(x, y, z):
        return x, y, z
    
    r = vector(rnd.random(), rnd.random(), 0)
    rx, ry, rz = r
    

    if math.sqrt(rx**2 + ry**2 + rz**2) <= 1:
        Cin.append(r)
        plt.plot(rx,ry,".", color='tomato')
        
    else:
        Cout.append(r)
        plt.plot(rx,ry,'.', color='teal')

mpi = 4*len(Cin)/(len(Cin) + len(Cout))
print(mpi)
# Out:
# 3.1252

# %%
fig = plt.figure(figsize = [4, 4], linewidth = 50)
Cin = []
Cout = []
for i in range(10000):
    def vector(x, y, z):
        return x, y, z
    
    r = vector(rnd.uniform(-1,1), rnd.uniform(-1,1), 0)
    rx, ry, rz = r
    

    if math.sqrt(rx**2 + ry**2 + rz**2) <= 1:
        Cin.append(r)
        plt.plot(rx,ry,".", color='tomato')
        
    else:
        Cout.append(r)
        plt.plot(rx,ry,'.', color='teal')

mpi = 4*len(Cin)/(len(Cin) + len(Cout))
print(mpi)
# Out:
# 3.1464

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
Cin = []
Cout = []
for i in range(10000):
    def vector(x, y, z):
        return x, y, z
    
    r = vector(rnd.random(), rnd.random(), rnd.random())
    rx, ry, rz = r
    

    if math.sqrt(rx**2 + ry**2 + rz**2) <= 1:
        Cin.append(r)
        ax.scatter(rx, ry, rz,".", color='tomato')
        
    else:
        Cout.append(r)
        ax.scatter(rx, ry, rz,".", color='teal')
mpi = 6*len(Cin)/(len(Cin) + len(Cout))
print(mpi)
# Out:
# 3.1752
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
